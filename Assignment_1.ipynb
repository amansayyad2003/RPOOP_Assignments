# %%
class Rectangle:
    def __init__(self, length, breadth):
        self.__length = length
        self.__breadth = breadth
            
    def get_length(self):
        return self.__length
    
    def set_length(self, length):
        self.__length = length
        
    def get_breadth(self):
        return self.__breadth
    
    def set_breadth(self, breadth):
        self.__breadth = breadth
        
    def area(self):
        return self.__length*self.__breadth
    
    def perimeter(self):
        return 2 * (self.__length + self.__breadth)
    
    def len_diagonal(self):
        return (self.__length**2 + self.__breadth**2)**(1/2)

# %%
print("Creating the rectangle\n")
length = int(input("Enter the length of rectangle\n"))
breadth = int(input("Enter the breadth of rectangle\n"))
rectangle1 = Rectangle(length, breadth)
print("Rectangle created !!\n")
while(True):
    print("Choose the operation you want to perform on Rectangle\n")
    num = int(input("\t1. Find Area\n\t2. Find perimeter\n\t3. Get length of diagonal\n\t4. Get length\n\t5. Get breadth\n\t6. Set length\n\t7. Set breadth\n\t8. Exit\n"))
    if(num == 1):
        print("Area of rectangle: length x breadth = ", rectangle1.area() , "\n")
    elif(num == 2):
        print("Perimeter of rectangle: 2 x (length + breadth) = ", rectangle1.perimeter(), "\n")
    elif(num == 3):
        print("length of diagonal: sqrt(length^2 + bredth^2) = ", rectangle1.len_diagonal(), "\n")
    elif(num == 4):
        print("Length of rectangle: ", rectangle1.get_length(), "\n")
    elif(num == 5):
        print("Breadth of rectangle: ", rectangle1.get_breadth(), "\n")
    elif(num == 6):
        length = int(input("Enter the new length of rectangle: "))
        rectangle1.set_length(length)
        print("Length has updated\n")
    elif(num == 7):
        breadth = int(input("Enter the new breadth of rectangle: "))
        rectangle1.set_breadth(breadth)
        print("Breadth has updated\n")
    elif(num == 8):
        break
    else:
        print("Give valid input\n")
# Out:
# Creating the rectangle
#
# Enter the length of rectangle
# 12
# Enter the breadth of rectangle
# 2
# Rectangle created !!
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 1
# Area of rectangle: length x breadth =  24
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 2
# Perimeter of rectangle: 2 x (length + breadth) =  28
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 3
# length of diagonal: sqrt(length^2 + bredth^2) =  12.165525060596439
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 4
# Length of rectangle:  12
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 5
# Breadth of rectangle:  2
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 6
# Enter the new length of rectangle: 23
# Length has updated
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 7
# Enter the new breadth of rectangle: 56
# Breadth has updated
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 4
# Length of rectangle:  23
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 5
# Breadth of rectangle:  56
#
# Choose the operation you want to perform on Rectangle
#
# 	1. Find Area
# 	2. Find perimeter
# 	3. Get length of diagonal
# 	4. Get length
# 	5. Get breadth
# 	6. Set length
# 	7. Set breadth
# 	8. Exit
# 8
